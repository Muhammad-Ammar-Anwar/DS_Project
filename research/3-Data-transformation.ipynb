# %%
import os

# %%
# %pwd
# Out:
# '/home/ammar/Documents/Learning/MLOps/DS_PROJECT/research'

# %%
os.chdir("../")
# %pwd
# Out:
# '/home/ammar/Documents/Learning/MLOps/DS_PROJECT'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.DS_PROJECT.constants import *
from src.DS_PROJECT.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import os 
from src.DS_PROJECT import logger 
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self,config: DataTransformationConfig):
        self.config = config

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)

        train,test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir,"train.csv"), index = False)
        test.to_csv(os.path.join(self.config.root_dir,"test.csv"),index = False)

        logger.info("Splitted data into training and test set")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_transformation_config()
    data_validation = DataTransformation(config=data_validation_config)
    data_validation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2025-12-06 03:58:37,637]: INFO : common : yaml file: config/config.yaml loaded successfully:
# [2025-12-06 03:58:37,638]: INFO : common : yaml file: params.yaml loaded successfully:
# [2025-12-06 03:58:37,639]: INFO : common : yaml file: schema.yaml loaded successfully:
# [2025-12-06 03:58:37,640]: INFO : common : created directory at: artifacts:
# [2025-12-06 03:58:37,640]: INFO : common : created directory at: artifacts/data_transformation:
# [2025-12-06 03:58:37,655]: INFO : 2883073124 : Splitted data into training and test set:
# [2025-12-06 03:58:37,655]: INFO : 2883073124 : (1199, 12):
# [2025-12-06 03:58:37,656]: INFO : 2883073124 : (400, 12):
# (1199, 12)
# (400, 12)
